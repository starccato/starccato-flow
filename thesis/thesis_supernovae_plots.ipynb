# %%
from starccato_flow.supernovae.supernovae import Supernovae
from starccato_flow.plotting.sky import plot_galactic_supernovae_polar_hemispheres
# Out:
# MPS device found

# %% [markdown]
# ### Configs

# %%
font_family = "sans-serif"
font_name = "Futura"

# %%
supernovae_simple = Supernovae(complex=False)
supernovae_complex = Supernovae(complex=True)
# Out:
# ✓ Loaded 1934076 supernova locations from /Users/tarineccleston/Desktop/starccato/starccato-flow/../data/supernovae/exploded_supernovae_t100_sf5.csv

# %% [markdown]
# ### R vs. Galactic Supernovae Surface Density Plot

# %%
supernovae_simple._plot_surface_density(
    fname="../../2025-Statistics-Masters-Thesis/figures/supernovae/supernovae_surface_density_simple.pdf",
    font_family=font_family,
    font_name=font_name,
    transparent=False
)

# %% [markdown]
# ### Simple Galactic Supernovae Distribution

# %%
supernovae_simple.plot_galactic_distribution(
    fname_xy="../../2025-Statistics-Masters-Thesis/figures/supernovae/supernovae_galactic_distribution_simple.pdf",
    font_family=font_family,
    font_name=font_name,
    transparent=False,
    background="white"
)
# Out:
# [<Figure size 570.866x570.866 with 1 Axes>]

# %% [markdown]
# ### Complex Galactic Supernovae Distribution (what we end up using)

# %%
supernovae_complex.plot_galactic_distribution(
    fname_xy="../../2025-Statistics-Masters-Thesis/figures/supernovae/supernovae_galactic_distribution_complex.pdf",
    font_family=font_family,
    font_name=font_name,
    transparent=False,
    background="white"
)
# Out:
# [<Figure size 570.866x570.866 with 1 Axes>]

# %% [markdown]
# ### Curriculum Learning -- Sampled Supernovae

# %%
supernovae_complex.sample_supernovae_for_epoch(
    epoch=0,
    n_samples=18000,
    num_epochs=256,
    exponential=True,
    fname="../../2025-Statistics-Masters-Thesis/figures/supernovae/first_sampled_supernovae_galactic_distribution_complex.pdf",
    font_family=font_family,
    font_name=font_name,
    background="white"
)

supernovae_complex.sample_supernovae_for_epoch(
    epoch=256,
    n_samples=18000,
    num_epochs=256,
    exponential=True,
    fname="../../2025-Statistics-Masters-Thesis/figures/supernovae/final_sampled_supernovae_galactic_distribution_complex.pdf",
    font_family=font_family,
    font_name=font_name,
    background="white"
)
# Out:
# (array([4.77237593, 4.79375317, 4.93677151, ..., 4.81087121, 5.23006659,
#         4.83145458]),
#  array([-0.30327909, -0.28491224, -0.02968352, ..., -0.24519088,
#          0.52722546, -0.27522585]),
#  array([9.92560523, 9.92972036, 7.89836908, ..., 9.88420997, 9.87038113,
#         9.56181079]))

# %%
ccsn = Supernovae(complex=True)  # Use a rotation offset of 90 degrees for the galactic plane

plot_galactic_supernovae_polar_hemispheres(
    ccsn,
    show_constellation_borders=True,
    show_detectors=True,
    format="thesis",
    fname="../../2025-Statistics-Masters-Thesis/figures/supernovae/supernovae_galactic_distribution_sky_plot.pdf",
    transparent=False,
    background="white",
    font_family=font_family,
    coastline=True,
    n_background_supernovae=20000,
    galaxy=True,
    constellations=True,
    font_name=font_name,
)
# Out:
# ✓ Loaded 1934076 supernova locations from /Users/tarineccleston/Desktop/starccato/starccato-flow/../data/supernovae/exploded_supernovae_t100_sf5.csv
# 691
# Constellation file audit: 88 OK, 0 with problems (out of 88 total)
# Orion: n_segments=21, n_hip_tokens=42 (expect 42)
#   segment 0: HIP 26727 (85.1896964235, -1.9425722364)  <->  HIP 26311 (84.0533893423, -1.2019198264)
#   segment 1: HIP 26311 (84.0533893423, -1.2019198264)  <->  HIP 25930 (83.0016696791, -0.2990920389)
#   segment 2: HIP 28691 (90.8640264446, 19.690561014)  <->  HIP 29426 (92.9849825735, 14.2087650799)
#   segment 3: HIP 29426 (92.9849825735, 14.2087650799)  <->  HIP 29038 (91.8930201823, 14.7684717008)
#   segment 4: HIP 29038 (91.8930201823, 14.7684717008)  <->  HIP 27913 (88.5957602571, 20.2761745489)
#   segment 5: HIP 29426 (92.9849825735, 14.2087650799)  <->  HIP 28614 (90.5958282143, 9.64727656)
#   segment 6: HIP 28614 (90.5958282143, 9.64727656)  <->  HIP 27989 (88.7929385961, 7.4070627358)
#   segment 7: HIP 27989 (88.7929385961, 7.4070627358)  <->  HIP 26727 (85.1896964235, -1.9425722364)
#   segment 8: HIP 26727 (85.1896964235, -1.9425722364)  <->  HIP 27366 (86.9391202317, -9.6696047767)
#   segment 9: HIP 27366 (86.9391202317, -9.6696047767)  <->  HIP 24436 (78.6344681221, -8.2016405511)
#   segment 10: HIP 24436 (78.6344681221, -8.2016405511)  <->  HIP 25930 (83.0016696791, -0.2990920389)
#   segment 11: HIP 25930 (83.0016696791, -0.2990920389)  <->  HIP 25336 (81.2827627614, 6.3497022322)
#   segment 12: HIP 25336 (81.2827627614, 6.3497022322)  <->  HIP 26207 (83.7844878884, 9.9341584192)
#   segment 13: HIP 26207 (83.7844878884, 9.9341584192)  <->  HIP 27989 (88.7929385961, 7.4070627358)
#   segment 14: HIP 25336 (81.2827627614, 6.3497022322)  <->  HIP 22449 (72.4600441319, 6.9612756817)
#   segment 15: HIP 22449 (72.4600441319, 6.9612756817)  <->  HIP 22549 (72.8015162291, 5.6051039635)
#   segment 16: HIP 22549 (72.8015162291, 5.6051039635)  <->  HIP 22730 (73.3448858737, 2.5082250489)
#   segment 17: HIP 22730 (73.3448858737, 2.5082250489)  <->  HIP 23123 (74.6370913837, 1.7140157857)
#   segment 18: HIP 22449 (72.4600441319, 6.9612756817)  <->  HIP 22509 (72.6530072896, 8.9001758474)
#   segment 19: HIP 22509 (72.6530072896, 8.9001758474)  <->  HIP 22845 (73.7238661658, 10.1508330996)
#   segment 20: HIP 29038 (91.8930201823, 14.7684717008)  <->  HIP 28614 (90.5958282143, 9.64727656)
#
# ============================================================
# Galactic Center Direction:
#   RA:  4.649646 rad = 266.41°
#   Dec: -0.505032 rad = -28.94°
# ============================================================
#
# <class 'matplotlib.path.Path'>
# <class 'type'>
# <class 'matplotlib.path.Path'>
# <class 'type'>
# <class 'matplotlib.path.Path'>
# <class 'type'>
# 962
# (8, 2)
# /Users/tarineccleston/Desktop/starccato/starccato-flow/.venv/lib/python3.9/site-packages/matplotlib/backends/backend_pdf.py:1758: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   img = Image.fromarray(rgb8, mode='P')
# /Users/tarineccleston/Desktop/starccato/starccato-flow/.venv/lib/python3.9/site-packages/matplotlib/backends/backend_pdf.py:1758: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   img = Image.fromarray(rgb8, mode='P')

# %%
import subprocess

# Add all files
subprocess.run(["git", "pull"], cwd="../../2025-Statistics-Masters-Thesis")
subprocess.run(["git", "add", "."], cwd="../../2025-Statistics-Masters-Thesis")
# Commit
subprocess.run(["git", "commit", "-m", "Update Plots"], cwd="../../2025-Statistics-Masters-Thesis")
# Push
subprocess.run(["git", "push"], cwd="../../2025-Statistics-Masters-Thesis")
# Out:
# Already up to date.
# [main 004bee7] Update Plots
#  6 files changed, 0 insertions(+), 0 deletions(-)
# To github.com:the-tarin/2025-Statistics-Masters-Thesis.git
#    66bcdf1..004bee7  main -> main
# CompletedProcess(args=['git', 'push'], returncode=0)
