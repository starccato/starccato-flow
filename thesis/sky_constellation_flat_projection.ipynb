# %% [markdown]
# # Constellation Flat Projection (Portrait A4)
#
# This notebook generates a flat projection of constellations with:
# - **Northern skies** on the top half
# - **Southern skies** on the bottom half
# - Portrait A4 page format (14.5 x 19 cm)
# - Constellation stick figures and borders
# - Star data from Hipparcos catalog

# %%
import numpy as np
import matplotlib.pyplot as plt
from starccato_flow.plotting.sky import plot_galactic_supernovae_polar_hemispheres

# %% [markdown]
# ## Configuration: Flat All-Sky Projection
#
# Create a complete flat projection with northern skies on top and southern on bottom:

# %%
# Flat all-sky projection configuration
OUTPUT_PATH = "../../2025-Statistics-Masters-Thesis/figures/artwork/sky_constellation_flat_projection.pdf"

# Portrait A4 page: 14.5 cm × 19 cm
PAGE_WIDTH_CM = 14.5
PAGE_HEIGHT_CM = 19.0
PAGE_DPI = 300

PLOT_CONFIG = {
    "background": "white",
    "font_family": "sans-serif",
    "font_name": "Futura",
}

# %% [markdown]
# ## Generate Flat All-Sky Projection
#
# Create the complete flat projection with constellations and stars:

# %%
from starccato_flow.plotting.sky_flat import plot_flat_constellation_projection
import importlib
import starccato_flow.plotting.sky_flat
importlib.reload(starccato_flow.plotting.sky_flat)
from starccato_flow.plotting.sky_flat import plot_flat_constellation_projection

from starccato_flow.supernovae.supernovae import Supernovae
ccsn = Supernovae(complex=True)

# Generate the flat all-sky projection with top 1000 brightest stars
fig, ax = plot_flat_constellation_projection(
    output_path=OUTPUT_PATH,
    supernovae=ccsn,
    page_width_cm=PAGE_WIDTH_CM,
    page_height_cm=PAGE_HEIGHT_CM,
    page_dpi=PAGE_DPI,
    background=PLOT_CONFIG["background"],
    font_family=PLOT_CONFIG["font_family"],
    font_name=PLOT_CONFIG["font_name"],
    mag_limit=6.0,
    plot_stars=True,
)

# Quick test: verify data is in axes
print(f"Number of collections in axes: {len(ax.collections)}")
print(f"Number of lines in axes: {len(ax.lines)}")
if len(ax.collections) > 0:
    print(f"First collection offsets shape: {ax.collections[0].get_offsets().shape}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from starccato_flow.plotting.sky_flat import plot_flat_constellation_projection
#       2 import importlib
#       3 import starccato_flow.plotting.sky_flat
#
# File ~/Desktop/starccato/starccato-flow/src/starccato_flow/plotting/__init__.py:68
#      64     return np.linspace(-53 / 4096, (length - 53) / 4096, length) * 1000 # convert to milliseconds
#      67 # Import plotting functions from submodules
# ---> 68 from .signals import (
#      69     plot_signal_grid,
#      70     plot_reconstruction,
#      71     plot_single_signal,
#      72     plot_signal_distribution
#      73 )
#      75 from .losses import (
#      76     plot_loss,
#      77     plot_gradients
#      78 )
#      80 from .parameters import (
#      81     plot_parameter_distribution,
#      82     plot_parameter_distributions,
#      83     plot_corner
#      84 )
#
# File ~/Desktop/starccato/starccato-flow/src/starccato_flow/plotting/signals.py:11
#       9 import matplotlib.patches as mpatches
#      10 import matplotlib.lines as mlines
# ---> 11 import torch
#      12 from . import set_plot_style, get_time_axis
#      13 from ..utils.defaults_plotting import (
#      14     SIGNAL_COLOUR, GENERATED_SIGNAL_COLOUR, DEFAULT_FONT_FAMILY,
#      15     DEFAULT_FONT, SIGNAL_LIM_UPPER, SIGNAL_LIM_LOWER, PARAMETER_LABELS, CM_TO_INCHES
#      16 )
#
# File ~/Desktop/starccato/starccato-flow/.venv/lib/python3.9/site-packages/torch/__init__.py:2630
#    2627 if not _running_with_deploy():
#    2628     from torch import compiler as compiler
# -> 2630     class _TritonLibrary:
#    2631         lib = torch.library.Library("triton", "DEF")
#    2632         ops_table: dict[tuple[str, str], _Callable] = {}
#
# File ~/Desktop/starccato/starccato-flow/.venv/lib/python3.9/site-packages/torch/__init__.py:2631, in _TritonLibrary()
#    2630 class _TritonLibrary:
# -> 2631     lib = torch.library.Library("triton", "DEF")
#    2632     ops_table: dict[tuple[str, str], _Callable] = {}
#    2634     @classmethod
#    2635     def registerOp(cls, op_key, full_schema, op_impl, dispatch_key):
#
# File ~/Desktop/starccato/starccato-flow/.venv/lib/python3.9/site-packages/torch/library.py:109, in Library.__init__(self, ns, kind, dispatch_key)
#     107 frame = traceback.extract_stack(limit=3)[0]
#     108 filename, lineno = frame.filename, frame.lineno
# --> 109 self.m: Optional[Any] = torch._C._dispatch_library(
#     110     kind, ns, dispatch_key, filename, lineno
#     111 )
#     112 self.ns = ns
#     113 self._op_defs: set[str] = set()
#
# RuntimeError: Only a single TORCH_LIBRARY can be used to register the namespace triton; please put all of your definitions in a single TORCH_LIBRARY block.  If you were trying to specify implementations, consider using TORCH_LIBRARY_IMPL (which can be duplicated).  If you really intended to define operators for a single namespace in a distributed way, you can use TORCH_LIBRARY_FRAGMENT to explicitly indicate this.  Previous registration of TORCH_LIBRARY was registered at /dev/null:2630; latest registration was registered at /dev/null:2630

# %%
# Force reload of the module
import sys
for module_name in list(sys.modules.keys()):
    if 'starccato_flow' in module_name:
        del sys.modules[module_name]

# Fresh import
from starccato_flow.plotting.sky_flat import plot_flat_constellation_projection
from starccato_flow.supernovae.supernovae import Supernovae

ccsn = Supernovae(complex=True)

# Generate the flat all-sky projection
fig, ax = plot_flat_constellation_projection(
    output_path=OUTPUT_PATH,
    supernovae=ccsn,
    page_width_cm=PAGE_WIDTH_CM,
    page_height_cm=PAGE_HEIGHT_CM,
    page_dpi=PAGE_DPI,
    background=PLOT_CONFIG["background"],
    font_family=PLOT_CONFIG["font_family"],
    font_name=PLOT_CONFIG["font_name"],
    mag_limit=6.0,
    plot_stars=True,
)

print(f"✓ Projection complete")
print(f"  Collections in axes: {len(ax.collections)}")
print(f"  Border segments rendered")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 8
#       5         del sys.modules[module_name]
#       7 # Fresh import
# ----> 8 from starccato_flow.plotting.sky_flat import plot_flat_constellation_projection
#       9 from starccato_flow.supernovae.supernovae import Supernovae
#      11 ccsn = Supernovae(complex=True)
#
# File ~/Desktop/starccato/starccato-flow/src/starccato_flow/plotting/__init__.py:68
#      64     return np.linspace(-53 / 4096, (length - 53) / 4096, length) * 1000 # convert to milliseconds
#      67 # Import plotting functions from submodules
# ---> 68 from .signals import (
#      69     plot_signal_grid,
#      70     plot_reconstruction,
#      71     plot_single_signal,
#      72     plot_signal_distribution
#      73 )
#      75 from .losses import (
#      76     plot_loss,
#      77     plot_gradients
#      78 )
#      80 from .parameters import (
#      81     plot_parameter_distribution,
#      82     plot_parameter_distributions,
#      83     plot_corner
#      84 )
#
# File ~/Desktop/starccato/starccato-flow/src/starccato_flow/plotting/signals.py:11
#       9 import matplotlib.patches as mpatches
#      10 import matplotlib.lines as mlines
# ---> 11 import torch
#      12 from . import set_plot_style, get_time_axis
#      13 from ..utils.defaults_plotting import (
#      14     SIGNAL_COLOUR, GENERATED_SIGNAL_COLOUR, DEFAULT_FONT_FAMILY,
#      15     DEFAULT_FONT, SIGNAL_LIM_UPPER, SIGNAL_LIM_LOWER, PARAMETER_LABELS, CM_TO_INCHES
#      16 )
#
# File ~/Desktop/starccato/starccato-flow/.venv/lib/python3.9/site-packages/torch/__init__.py:2630
#    2627 if not _running_with_deploy():
#    2628     from torch import compiler as compiler
# -> 2630     class _TritonLibrary:
#    2631         lib = torch.library.Library("triton", "DEF")
#    2632         ops_table: dict[tuple[str, str], _Callable] = {}
#
# File ~/Desktop/starccato/starccato-flow/.venv/lib/python3.9/site-packages/torch/__init__.py:2631, in _TritonLibrary()
#    2630 class _TritonLibrary:
# -> 2631     lib = torch.library.Library("triton", "DEF")
#    2632     ops_table: dict[tuple[str, str], _Callable] = {}
#    2634     @classmethod
#    2635     def registerOp(cls, op_key, full_schema, op_impl, dispatch_key):
#
# File ~/Desktop/starccato/starccato-flow/.venv/lib/python3.9/site-packages/torch/library.py:109, in Library.__init__(self, ns, kind, dispatch_key)
#     107 frame = traceback.extract_stack(limit=3)[0]
#     108 filename, lineno = frame.filename, frame.lineno
# --> 109 self.m: Optional[Any] = torch._C._dispatch_library(
#     110     kind, ns, dispatch_key, filename, lineno
#     111 )
#     112 self.ns = ns
#     113 self._op_defs: set[str] = set()
#
# RuntimeError: Only a single TORCH_LIBRARY can be used to register the namespace triton; please put all of your definitions in a single TORCH_LIBRARY block.  If you were trying to specify implementations, consider using TORCH_LIBRARY_IMPL (which can be duplicated).  If you really intended to define operators for a single namespace in a distributed way, you can use TORCH_LIBRARY_FRAGMENT to explicitly indicate this.  Previous registration of TORCH_LIBRARY was registered at /dev/null:2630; latest registration was registered at /dev/null:2630

# %% [markdown]
# ## About This Projection
#
# This notebook creates a **flat all-sky projection** using an equirectangular (plate-carrée) projection:
# - **X-axis**: Right Ascension (RA) from 0° to 360°
# - **Y-axis**: Declination (Dec) from -90° to +90°
# - **Top half**: Northern celestial hemisphere (Dec > 0)
# - **Bottom half**: Southern celestial hemisphere (Dec < 0)
#
# The visualization shows:
# - **Constellation stick figures**: Lines connecting bright stars in each constellation
# - **Constellation borders**: IAU constellation boundaries
#
# The equirectangular projection is linear and perfect for:
# - Printing on portrait A4 pages
# - Showing the complete celestial sphere with proper scale
# - Displaying all 88 IAU constellations

# %%
# Verify the file was created
import os
if os.path.exists(OUTPUT_PATH):
    file_size_mb = os.path.getsize(OUTPUT_PATH) / (1024**2)
    print(f"✓ File created successfully: {OUTPUT_PATH}")
    print(f"✓ File size: {file_size_mb:.2f} MB")
    print(f"✓ Page dimensions: {PAGE_WIDTH_CM} cm × {PAGE_HEIGHT_CM} cm")
    print(f"✓ Resolution: {PAGE_DPI} DPI")
else:
    print(f"✗ File not found: {OUTPUT_PATH}")
# Out:
# ✓ File created successfully: ../../2025-Statistics-Masters-Thesis/figures/artwork/sky_constellation_flat_projection.pdf
# ✓ File size: 1.01 MB
# ✓ Page dimensions: 14.5 cm × 19.0 cm
# ✓ Resolution: 300 DPI

# %%
import subprocess

# Add all files
subprocess.run(["git", "pull"], cwd="../../2025-Statistics-Masters-Thesis")
subprocess.run(["git", "add", "."], cwd="../../2025-Statistics-Masters-Thesis")
# Commit
subprocess.run(["git", "commit", "-m", "Update Plots"], cwd="../../2025-Statistics-Masters-Thesis")
# Push
subprocess.run(["git", "push"], cwd="../../2025-Statistics-Masters-Thesis")
# Out:
# Already up to date.
# [main 3bab79a] Update Plots
#  2 files changed, 0 insertions(+), 0 deletions(-)
# To github.com:the-tarin/2025-Statistics-Masters-Thesis.git
#    28e3176..3bab79a  main -> main
# CompletedProcess(args=['git', 'push'], returncode=0)
