# %%
import numpy as np
from starccato_flow.supernovae.supernovae import Supernovae
# Out:
# MPS device found
# 630763148.816

# %%
font_family = "Sans-serif"
font_name = "Futura"

# %%
supernovae_complex = Supernovae(complex=True)

fontsize_title = 22
fontsize_tick = 16
# Out:
# ✓ Loaded 1934076 supernova locations from /Users/tarineccleston/Desktop/starccato/starccato-flow/../data/supernovae/exploded_supernovae_t100_sf5.csv

# %%
supernovae_complex.plot_galactic_distribution(
    fname_xy="../../poster-presentation/supernovae_distribution_kpc.png",
    transparent=True,
    light_year=False,
    figsize=(27.5, 27.5),
    font_family=font_family,
    font_name=font_name,
    fontsize_title=fontsize_title,
    fontsize_tick=fontsize_tick,
)

supernovae_complex.plot_galactic_distribution(
    fname_xy="../../poster-presentation/supernovae_distribution_light_years.svg",
    transparent=True,
    light_year=True,
    figsize=(27.5, 27.5),
    font_family=font_family,
    font_name=font_name,
    fontsize_title=fontsize_title,
    fontsize_tick=fontsize_tick,
)
# Out:
# [<Figure size 1082.68x1082.68 with 1 Axes>]

# %%
# # Generate and save epoch plots at lower resolution for smoother GIF
# epoch_dir = "../outdir/flow_matching/gif_data"
# n_samples = 18000
# num_epochs = 256
# frame_skip = 4  # Only save every 4th epoch to reduce GIF size

# print(f"Generating {num_epochs // frame_skip} epoch frames to {epoch_dir}...")
# for epoch in range(num_epochs):
#     # Skip epochs to reduce total frames
#     if epoch % frame_skip != 0:
#         continue
        
#     supernovae_complex.sample_supernovae_for_epoch(
#         epoch=epoch,
#         n_samples=n_samples,
#         num_epochs=num_epochs,
#         exponential=True,
#         epoch_dir=epoch_dir,
#         font_family=font_family,
#         font_name=font_name,
#         transparent=True
#     )

# # Now compile saved plots into GIF with optimization
# print("Compiling epoch plots into GIF...")
# supernovae_complex.create_epoch_gif(
#     epoch_dir=epoch_dir,
#     output_fname="../../poster-presentation/supernovae_curriculum.gif",
#     duration=200,  # Slower playback (200ms per frame)
#     num_epochs=num_epochs
# )
