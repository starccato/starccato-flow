# %%
from starccato_flow.data.s_theta import sTheta
from starccato_flow.training.trainer_flow_matching_multi import FlowMatchingTrainerMulti

# %%
trainer = FlowMatchingTrainerMulti(
    dataset=sTheta(noise=True, curriculum=False),
    batch_size=128,
    num_epochs=100)

trainer.train()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 FlowMatchingTrainerMulti.train()
#
# TypeError: train() missing 1 required positional argument: 'self'
