# %%
from starccato_flow.training.maf_trainer import train_flow
# Out:
# /Users/tarineccleston/Desktop/starccato/starccato-flow/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
train_flow()
# Out:
# Epoch 1/50 NLL: inf
# Epoch 2/50 NLL: nan
# Epoch 3/50 NLL: nan
# Epoch 4/50 NLL: nan
# Epoch 5/50 NLL: nan
# Epoch 6/50 NLL: nan
# Epoch 7/50 NLL: nan
# Epoch 8/50 NLL: nan
# Epoch 9/50 NLL: nan
# Epoch 10/50 Batch NLL: nan
# Epoch 10/50 NLL: nan
# Epoch 11/50 NLL: nan
# Epoch 12/50 NLL: nan
# Epoch 13/50 NLL: nan
# Epoch 14/50 NLL: nan
# Epoch 15/50 NLL: nan
# Epoch 16/50 NLL: nan
# Epoch 17/50 NLL: nan
# Epoch 18/50 NLL: nan
# Epoch 19/50 NLL: nan
# Epoch 20/50 Batch NLL: nan
# Epoch 20/50 NLL: nan
# Epoch 21/50 NLL: nan
# Epoch 22/50 NLL: nan
# Epoch 23/50 NLL: nan
# Epoch 24/50 NLL: nan
# Epoch 25/50 NLL: nan
# Epoch 26/50 NLL: nan
# Epoch 27/50 NLL: nan
# Epoch 28/50 NLL: nan
# Epoch 29/50 NLL: nan
# Epoch 30/50 Batch NLL: nan
# Epoch 30/50 NLL: nan
# Epoch 31/50 NLL: nan
# Epoch 32/50 NLL: nan
# Epoch 33/50 NLL: nan
# Epoch 34/50 NLL: nan
# Epoch 35/50 NLL: nan
# Epoch 36/50 NLL: nan
# Epoch 37/50 NLL: nan
# Epoch 38/50 NLL: nan
# Epoch 39/50 NLL: nan
# ...
