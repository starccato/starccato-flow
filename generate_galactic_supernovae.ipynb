# %%
from starccato_flow.sky.sky import Sky
import numpy as np

# %%
sky = Sky(ra=0.0, dec=0.0)
supernovae = sky.generate_galactic_supernovae(num_supernovae=100000)

# plot supernova in 3d plot, and 2d plot
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(12, 6))
ax1 = fig.add_subplot(121, projection='3d')
ax2 = fig.add_subplot(122)
x = supernovae[:, 0]
y = supernovae[:, 1]    
z = supernovae[:, 2]
ax1.scatter(x, y, z, s=1)
ax1.set_xlabel('X (kpc)')
ax1.set_ylabel('Y (kpc)')
ax1.set_zlabel('Z (kpc)')
ax1.set_title('3D Distribution of Galactic Supernovae')
ax2.scatter(x, y, s=1)
ax2.set_xlabel('X (kpc)')
ax2.set_ylabel('Y (kpc)')
ax2.set_title('2D Projection of Galactic Supernovae')
plt.show()
# Out:
# [[-2.19897279e-01 -1.80976893e-01  6.03747661e-02]
#  [ 3.17046394e+00 -3.96523790e+00  7.36522188e-02]
#  [-1.69906440e+00  1.49381018e+00  7.32194763e-02]
#  ...
#  [-4.81757538e+00 -4.63780465e-01 -8.12097062e-02]
#  [ 2.79680143e+00 -7.84651027e+00  3.84964056e-03]
#  [ 1.42333754e-01  2.07968023e+00 -6.20292298e-03]]
